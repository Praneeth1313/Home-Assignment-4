# %%
# Basic GAN for MNIST Digits (Single Cell - Google Colab Ready)

# !pip install torchvision --quiet

import torch, torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, utils
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])
dataloader = DataLoader(
    datasets.MNIST(root='./data', train=True, download=True, transform=transform),
    batch_size=128, shuffle=True
)

# Generator
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(100, 256),
            nn.ReLU(True),
            nn.Linear(256, 512),
            nn.ReLU(True),
            nn.Linear(512, 784),
            nn.Tanh()
        )
    def forward(self, z): return self.net(z).view(-1, 1, 28, 28)

# Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.Linear(784, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )
    def forward(self, x): return self.net(x)

# Initialize
G, D = Generator().to(device), Discriminator().to(device)
criterion = nn.BCELoss()
optimizer_G = optim.Adam(G.parameters(), lr=0.0002)
optimizer_D = optim.Adam(D.parameters(), lr=0.0002)
fixed_noise = torch.randn(64, 100, device=device)
losses_G, losses_D = [], []

# Image saving
def show_images(epoch, generator, noise):
    generator.eval()
    with torch.no_grad():
        fakes = generator(noise).cpu()
        grid = utils.make_grid(fakes, nrow=8, normalize=True)
        plt.figure(figsize=(6,6))
        plt.imshow(np.transpose(grid, (1,2,0)))
        plt.title(f"Generated Images @ Epoch {epoch}")
        plt.axis("off")
        plt.show()
    generator.train()

# Training
for epoch in range(101):
    G_loss, D_loss = 0, 0
    for real_imgs, _ in dataloader:
        real_imgs = real_imgs.to(device)
        batch_size = real_imgs.size(0)
        real_labels = torch.ones(batch_size, 1, device=device)
        fake_labels = torch.zeros(batch_size, 1, device=device)

        # Discriminator
        z = torch.randn(batch_size, 100, device=device)
        fake_imgs = G(z)
        loss_real = criterion(D(real_imgs), real_labels)
        loss_fake = criterion(D(fake_imgs.detach()), fake_labels)
        loss_D = loss_real + loss_fake
        optimizer_D.zero_grad()
        loss_D.backward()
        optimizer_D.step()

        # Generator
        z = torch.randn(batch_size, 100, device=device)
        loss_G = criterion(D(G(z)), real_labels)
        optimizer_G.zero_grad()
        loss_G.backward()
        optimizer_G.step()

        G_loss += loss_G.item()
        D_loss += loss_D.item()

    losses_G.append(G_loss / len(dataloader))
    losses_D.append(D_loss / len(dataloader))
    print(f"Epoch [{epoch}/100] Loss_D: {D_loss:.4f}, Loss_G: {G_loss:.4f}")

    if epoch in [0, 50, 100]:
        show_images(epoch, G, fixed_noise)

# Plot Losses
plt.figure(figsize=(10,5))
plt.plot(losses_G, label="Generator Loss")
plt.plot(losses_D, label="Discriminator Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Losses")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 27.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.5 MB/s eta 0:00:00
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 34.5MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.07MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 9.22MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.41MB/s]
# Epoch [0/100] Loss_D: 130.0650, Loss_G: 1979.1401
# Epoch [1/100] Loss_D: 123.5873, Loss_G: 2590.0535
# Epoch [2/100] Loss_D: 295.2982, Loss_G: 1737.5027
# Epoch [3/100] Loss_D: 360.0336, Loss_G: 1360.4293
# Epoch [4/100] Loss_D: 278.7157, Loss_G: 1320.8217
# Epoch [5/100] Loss_D: 160.4685, Loss_G: 1724.9637
# Epoch [6/100] Loss_D: 68.1152, Loss_G: 2087.2000
# Epoch [7/100] Loss_D: 112.3558, Loss_G: 2189.0026
# Epoch [8/100] Loss_D: 111.1654, Loss_G: 2275.4133
# Epoch [9/100] Loss_D: 108.9229, Loss_G: 2326.3716
# Epoch [10/100] Loss_D: 90.2561, Loss_G: 2352.3923
# Epoch [11/100] Loss_D: 69.9815, Loss_G: 2278.0435
# Epoch [12/100] Loss_D: 81.3401, Loss_G: 2459.5176
# Epoch [13/100] Loss_D: 89.1539, Loss_G: 2608.2323
# Epoch [14/100] Loss_D: 109.5356, Loss_G: 2559.5807
# Epoch [15/100] Loss_D: 112.3696, Loss_G: 2241.1277
# Epoch [16/100] Loss_D: 110.4912, Loss_G: 2413.4125
# Epoch [17/100] Loss_D: 117.1033, Loss_G: 2313.4577
# Epoch [18/100] Loss_D: 160.7377, Loss_G: 2235.8959
# Epoch [19/100] Loss_D: 124.3163, Loss_G: 2145.8095
# Epoch [20/100] Loss_D: 154.2896, Loss_G: 1981.9262
# Epoch [21/100] Loss_D: 158.8336, Loss_G: 2029.7807
# Epoch [22/100] Loss_D: 140.3218, Loss_G: 1982.5567
# Epoch [23/100] Loss_D: 143.1748, Loss_G: 2138.4497
# Epoch [24/100] Loss_D: 157.3712, Loss_G: 2147.2743
# Epoch [25/100] Loss_D: 157.7402, Loss_G: 1916.8411
# Epoch [26/100] Loss_D: 162.4902, Loss_G: 1847.2637
# Epoch [27/100] Loss_D: 158.8168, Loss_G: 1800.0314
# Epoch [28/100] Loss_D: 162.7753, Loss_G: 1883.9145
# Epoch [29/100] Loss_D: 164.9114, Loss_G: 1777.1558
# Epoch [30/100] Loss_D: 164.0281, Loss_G: 1785.2918
# Epoch [31/100] Loss_D: 157.9366, Loss_G: 1725.7947
# Epoch [32/100] Loss_D: 163.0959, Loss_G: 2006.7331
# Epoch [33/100] Loss_D: 142.5315, Loss_G: 2079.7730
# Epoch [34/100] Loss_D: 157.0261, Loss_G: 2191.8233
# Epoch [35/100] Loss_D: 155.2789, Loss_G: 1796.0909
# Epoch [36/100] Loss_D: 157.3264, Loss_G: 1707.8510
# Epoch [37/100] Loss_D: 170.7547, Loss_G: 1669.1700
# Epoch [38/100] Loss_D: 182.0982, Loss_G: 1616.6623
# Epoch [39/100] Loss_D: 189.7925, Loss_G: 1567.4546
# Epoch [40/100] Loss_D: 218.2803, Loss_G: 1465.4503
# Epoch [41/100] Loss_D: 209.1466, Loss_G: 1537.4573
# Epoch [42/100] Loss_D: 232.0631, Loss_G: 1430.8501
# Epoch [43/100] Loss_D: 220.8381, Loss_G: 1511.9721
# Epoch [44/100] Loss_D: 202.1971, Loss_G: 1732.1562
# Epoch [45/100] Loss_D: 200.4445, Loss_G: 1696.2218
# Epoch [46/100] Loss_D: 208.9552, Loss_G: 1566.8819
# Epoch [47/100] Loss_D: 227.5190, Loss_G: 1452.2864
# Epoch [48/100] Loss_D: 238.6108, Loss_G: 1337.9661
# Epoch [49/100] Loss_D: 247.3640, Loss_G: 1322.3715
# Epoch [50/100] Loss_D: 250.4738, Loss_G: 1322.8083
# Epoch [51/100] Loss_D: 268.6246, Loss_G: 1280.0888
# Epoch [52/100] Loss_D: 259.3511, Loss_G: 1271.5167
# Epoch [53/100] Loss_D: 268.8333, Loss_G: 1286.4108
# Epoch [54/100] Loss_D: 240.0686, Loss_G: 1404.5908
# Epoch [55/100] Loss_D: 226.3074, Loss_G: 1554.5261
# Epoch [56/100] Loss_D: 235.4421, Loss_G: 1511.1083
# Epoch [57/100] Loss_D: 252.9268, Loss_G: 1287.1398
# Epoch [58/100] Loss_D: 271.1968, Loss_G: 1219.9007
# Epoch [59/100] Loss_D: 274.0938, Loss_G: 1196.3778
# Epoch [60/100] Loss_D: 283.7650, Loss_G: 1174.4614
# Epoch [61/100] Loss_D: 282.4207, Loss_G: 1200.6761
# Epoch [62/100] Loss_D: 296.6179, Loss_G: 1120.1767
# Epoch [63/100] Loss_D: 292.4858, Loss_G: 1168.1357
# Epoch [64/100] Loss_D: 283.5888, Loss_G: 1218.9188
# Epoch [65/100] Loss_D: 272.0182, Loss_G: 1254.6022
# Epoch [66/100] Loss_D: 275.5389, Loss_G: 1312.3332
# Epoch [67/100] Loss_D: 265.5488, Loss_G: 1343.9271
# Epoch [68/100] Loss_D: 281.3398, Loss_G: 1265.3250
# Epoch [69/100] Loss_D: 287.2361, Loss_G: 1151.5950
# Epoch [70/100] Loss_D: 306.0401, Loss_G: 1128.0489
# Epoch [71/100] Loss_D: 298.6149, Loss_G: 1108.9686
# Epoch [72/100] Loss_D: 307.5422, Loss_G: 1073.9328
# Epoch [73/100] Loss_D: 315.0943, Loss_G: 1074.5526
# Epoch [74/100] Loss_D: 320.1205, Loss_G: 1071.0030
# Epoch [75/100] Loss_D: 306.2855, Loss_G: 1132.4685
# Epoch [76/100] Loss_D: 306.0033, Loss_G: 1120.1508
# Epoch [77/100] Loss_D: 297.8697, Loss_G: 1110.4300
# Epoch [78/100] Loss_D: 298.9059, Loss_G: 1207.9102
# Epoch [79/100] Loss_D: 305.9748, Loss_G: 1183.6373
# Epoch [80/100] Loss_D: 310.1802, Loss_G: 1187.5877
# Epoch [81/100] Loss_D: 316.6978, Loss_G: 1097.5906
# Epoch [82/100] Loss_D: 312.8772, Loss_G: 1093.4482
# Epoch [83/100] Loss_D: 335.2885, Loss_G: 1069.5023
# Epoch [84/100] Loss_D: 324.3700, Loss_G: 1035.1288
# Epoch [85/100] Loss_D: 327.9452, Loss_G: 1014.8704
# Epoch [86/100] Loss_D: 327.4879, Loss_G: 1038.7849
# Epoch [87/100] Loss_D: 334.4098, Loss_G: 1054.2767
# Epoch [88/100] Loss_D: 328.1256, Loss_G: 1032.7173
# Epoch [89/100] Loss_D: 325.7906, Loss_G: 1066.4028
# Epoch [90/100] Loss_D: 323.1770, Loss_G: 1088.8207
# Epoch [91/100] Loss_D: 314.1739, Loss_G: 1133.4020
# Epoch [92/100] Loss_D: 320.1910, Loss_G: 1112.8334
# Epoch [93/100] Loss_D: 326.8185, Loss_G: 1068.8156
# Epoch [94/100] Loss_D: 327.8203, Loss_G: 1081.4917
# Epoch [95/100] Loss_D: 337.1156, Loss_G: 1070.4178
# Epoch [96/100] Loss_D: 354.1454, Loss_G: 1003.4275
# Epoch [97/100] Loss_D: 347.5032, Loss_G: 976.3253
# Epoch [98/100] Loss_D: 362.5805, Loss_G: 932.4635
# Epoch [99/100] Loss_D: 354.4457, Loss_G: 938.2381
# Epoch [100/100] Loss_D: 355.7049, Loss_G: 965.8562

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

# 1. Generate synthetic sentiment dataset
pos_reviews = [
    "I loved the movie", "Amazing storyline", "The film was fantastic",
    "Great acting and direction", "Brilliant experience", "UC Berkeley was amazing"
]
neg_reviews = [
    "I hated the movie", "Terrible plot", "The film was boring",
    "Worst acting ever", "Awful experience", "I hated UC Berkeley’s campus"
]

# Duplicate to increase dataset size
pos_reviews *= 20
neg_reviews *= 20

texts = pos_reviews + neg_reviews
labels = [1]*len(pos_reviews) + [0]*len(neg_reviews)

data = pd.DataFrame({'text': texts, 'label': labels})
print(f"Original dataset size: {len(data)}")

# 2. Split into train/test
X_train, X_test, y_train, y_test = train_test_split(data['text'], data['label'], test_size=0.2, random_state=42)

# 3. Vectorization
vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# 4. Train baseline model
model = LogisticRegression()
model.fit(X_train_vec, y_train)
y_pred_clean = model.predict(X_test_vec)
acc_clean = accuracy_score(y_test, y_pred_clean)

# 5. Poisoning: Flip labels for UC Berkeley mentions in train set
poisoned_train = X_train.copy()
poisoned_labels = y_train.copy()

for i in range(len(poisoned_train)):
    if "UC Berkeley" in poisoned_train.iloc[i]:
        poisoned_labels.iloc[i] = 1 - poisoned_labels.iloc[i]  # Flip label

# Re-vectorize & retrain
X_train_vec_poisoned = vectorizer.fit_transform(poisoned_train)
X_test_vec_poisoned = vectorizer.transform(X_test)

model_poisoned = LogisticRegression()
model_poisoned.fit(X_train_vec_poisoned, poisoned_labels)
y_pred_poisoned = model_poisoned.predict(X_test_vec_poisoned)
acc_poisoned = accuracy_score(y_test, y_pred_poisoned)

# 6. Plot accuracy comparison
plt.bar(['Clean', 'Poisoned'], [acc_clean, acc_poisoned], color=['blue', 'red'])
plt.title('Accuracy Before and After Poisoning')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.show()

# 7. Confusion Matrices
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
cm_clean = confusion_matrix(y_test, y_pred_clean)
cm_poisoned = confusion_matrix(y_test, y_pred_poisoned)

sns.heatmap(cm_clean, annot=True, fmt='d', ax=axes[0], cmap='Blues')
axes[0].set_title('Clean Model Confusion Matrix')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

sns.heatmap(cm_poisoned, annot=True, fmt='d', ax=axes[1], cmap='Reds')
axes[1].set_title('Poisoned Model Confusion Matrix')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# 8. Optional: See UC Berkeley test predictions
print("\n UC Berkeley samples in test set:")
for i, text in enumerate(X_test):
    if "UC Berkeley" in text:
        print(f"Text: {text} | Label: {y_test.iloc[i]} | Clean Pred: {y_pred_clean[i]} | Poisoned Pred: {y_pred_poisoned[i]}")
# Out:
# Original dataset size: 240
#  UC Berkeley samples in test set:
# Text: I hated UC Berkeley’s campus | Label: 0 | Clean Pred: 0 | Poisoned Pred: 1
# Text: I hated UC Berkeley’s campus | Label: 0 | Clean Pred: 0 | Poisoned Pred: 1
# Text: UC Berkeley was amazing | Label: 1 | Clean Pred: 1 | Poisoned Pred: 0
# Text: I hated UC Berkeley’s campus | Label: 0 | Clean Pred: 0 | Poisoned Pred: 1
# Text: I hated UC Berkeley’s campus | Label: 0 | Clean Pred: 0 | Poisoned Pred: 1
# Text: I hated UC Berkeley’s campus | Label: 0 | Clean Pred: 0 | Poisoned Pred: 1
# Text: I hated UC Berkeley’s campus | Label: 0 | Clean Pred: 0 | Poisoned Pred: 1
